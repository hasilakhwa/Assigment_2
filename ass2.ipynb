# %%
#Scenario 1: Grocery Shopping List
#You are creating a program to manage a grocery shopping list. Users should be able to add items,
#remove items, and display the current list.
 
grocery_list = []


for _ in range(4):
    print("\nOptions:")
    print("1. Add item to the list")
    print("2. Remove item from the list")
    print("3. Display current list")
    print("4. Exit")

    choice = input("Enter your number (1-4): ")

    if choice == "1":
        item = input("Enter the item to add: ")
        grocery_list.append(item)
        print(f"{item} has been added to the list.")
    elif choice == "2":
        if not grocery_list:
            print("The list is empty.")
        else:
            item = input("Enter the item to remove: ")
            if item in grocery_list:
                grocery_list.remove(item)
                print(f"{item} has been removed from the list.")
            else:
                print(f"{item} is not in the list.")
    elif choice == "3":
        if not grocery_list:
            print("The list is empty.")
        else:
            print("Current Grocery List:")
            for i, item in enumerate(grocery_list, 1):
                print(f"{i}. {item}")
    elif choice == "4":
        print("Exiting the program. Goodbye!")
        break
    else:
        print("Invalid choice. Please enter a number between 1 and 4.")
# Out:
# Options:
# 1. Add item to the list
# 2. Remove item from the list
# 3. Display current list
# 4. Exit

# %%
#Scenario 2: Student Grades
#You are managing student grades using a dictionary. You need to calculate the average grade.take
#atleast 5 Students grades & then calculate the average.


grades_dict = {}

for i in range(5):
    student_name = input(f"Enter the name of student {i+1}: ")
    student_grades = []
    for j in range(3):  
        grade = float(input(f"Enter grade {j+1} for {student_name}: "))
        student_grades.append(grade)
    grades_dict[student_name] = student_grades

total_grades = 0
for student_grades in grades_dict.values():
    total_grades += sum(student_grades)

total_students = len(grades_dict)
average_grade = total_grades / (total_students * 3) 


print("Average grade:", average_grade)
# Out:
# Average grade: 1326.0

# %%
#Scenario 3: Word Frequency Counter
#You are given a list of words, and you need to count the frequency of each word.
#word_list = ["apple", "banana", "apple", "orange", "banana", "grape", "apple"]

word_list = ["apple", "banana", "apple", "orange", "banana", "grape", "apple"]

word_freq = {}

for word in word_list:
    if word in word_freq:
        word_freq[word] += 1
    else:
        word_freq[word] = 1

for word, freq in word_freq.items():
    print(f"{word}: {freq}")
# Out:
# apple: 3
# banana: 2
# orange: 1
# grape: 1

# %%
#Scenario 3: Password Strength Checker
#You are creating a program to check the strength of passwords based on certain criteria.
# Password should be at least 8 characters long.
# Password should contain at least one digit.
# Password should contain at least one letter.

password = input("Enter your password: ")

length_check = False
digit_check = False
letter_check = False

if len(password) >= 8:
    length_check = True

for char in password:
    if char.isdigit():
        digit_check = True
    elif char.isalpha():
        letter_check = True

if length_check and digit_check and letter_check:
    print("Password is strong!")
else:
    print("Password is weak!")
    print("Criteria not met:")
    if not length_check:
        print("- Password should be at least 8 characters long.")
    if not digit_check:
        print("- Password should contain at least one digit.")
    if not letter_check:
        print("- Password should contain at least one letter.")
# Out:
# Password is weak!
# Criteria not met:
# - Password should be at least 8 characters long.
# - Password should contain at least one digit.
# - Password should contain at least one letter.

# %%
#Scenario 04: Voting System (Annual Employee Recognition Awards)
#You are developing a simple voting system for a contest. Users can vote for their Favorite option, and
#you need to count the votes.
#In a corporate setting, the HR department is organizing the Annual Employee Recognition Awards,
#where employees get the opportunity to vote for their colleagues nominated in different categories.
#The HR team has decided to use a simple voting system to collect and tally votes for the nominees in
#various award categories. The script provided will be utilized for this purpose.
#Candidates: The nominees for different award categories, such as "Employee of the Year," "Team
#Player of the Year," and "Innovation Award," are represented by the list of candidates: 'Candidate A,'
#'Candidate B,' and 'Candidate C.'
#Voting Process: Employees are requested to input the number of voters participating in the awards.
#Each voter is presented with a list of nominees, and they can vote for their preferred candidate by
#entering the corresponding number.
#Validation: The script ensures that the entered vote is within the valid range of candidates. If an
#employee enters an invalid vote, the system prompts them to choose a valid candidate.
#Recording Votes: The script records each vote for the selected candidate and prints a confirmation
#message indicating that the vote has been recorded.
#Results Display: Once all votes are collected, the system displays the voting results, showing the
#number of votes each candidate received in each category.
#Award Winners: Based on the voting results, the HR department can identify the winners for each
#award category and proceed with recognizing and rewarding the selected employees during the
#Annual Employee Recognition Ceremony.
#This script provides a straightforward and transparent way for employees to participate in the
#recognition process, fostering a sense of engagement and community within the organization. The
#HR team can use the collected votes to acknowledge and appreciate the efforts of outstanding
#employees in various aspects of their work.


candidates = {
    "Employee of the Year": ["Candidate A", "Candidate B", "Candidate C"],
    "Team Player of the Year": ["Candidate A", "Candidate B", "Candidate C"],
    "Innovation Award": ["Candidate A", "Candidate B", "Candidate C"]
}

votes = {award: {candidate: 0 for candidate in candidates[award]} for award in candidates}


num_voters = int(input("Enter the number of voters: "))

for _ in range(num_voters):
    print("Voter", _ + 1)
    for award, nominee_list in candidates.items():
        print(f"\nNominees for {award}:")
        for i, nominee in enumerate(nominee_list):
            print(f"{i+1}. {nominee}")
        while True:
            vote = int(input("Enter your vote (1, 2, or 3): "))
            if 1 <= vote <= 3:
                votes[award][nominee_list[vote - 1]] += 1
                print("Vote recorded.")
                break
            else:
                print("Invalid vote. Please choose a valid candidate.")


print("\nVoting Results:")
for award, candidate_votes in votes.items():
    print(f"\n{award}:")
    for candidate, vote_count in candidate_votes.items():
        print(f"{candidate}: {vote_count} votes")

print("\nAward Winners:")
for award, candidate_votes in votes.items():
    winner = max(candidate_votes, key=candidate_votes.get)
    print(f"{award}: {winner} - {candidate_votes[winner]} votes")
# Out:
# Voter 1
#
# Nominees for Employee of the Year:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Vote recorded.
#
# Nominees for Team Player of the Year:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Vote recorded.
#
# Nominees for Innovation Award:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Vote recorded.
# Voter 2
#
# Nominees for Employee of the Year:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Vote recorded.
#
# Nominees for Team Player of the Year:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Vote recorded.
#
# Nominees for Innovation Award:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Vote recorded.
# Voter 3
#
# Nominees for Employee of the Year:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Vote recorded.
#
# Nominees for Team Player of the Year:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Vote recorded.
#
# Nominees for Innovation Award:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Vote recorded.
# Voter 4
#
# Nominees for Employee of the Year:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Vote recorded.
#
# Nominees for Team Player of the Year:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Vote recorded.
#
# Nominees for Innovation Award:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Vote recorded.
# Voter 5
#
# Nominees for Employee of the Year:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Vote recorded.
#
# Nominees for Team Player of the Year:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Vote recorded.
#
# Nominees for Innovation Award:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Vote recorded.
#
# Voting Results:
#
# Employee of the Year:
# Candidate A: 0 votes
# Candidate B: 0 votes
# Candidate C: 5 votes
#
# Team Player of the Year:
# Candidate A: 0 votes
# Candidate B: 1 votes
# Candidate C: 4 votes
#
# Innovation Award:
# Candidate A: 0 votes
# Candidate B: 0 votes
# Candidate C: 5 votes
#
# Award Winners:
# Employee of the Year: Candidate C - 5 votes
# Team Player of the Year: Candidate C - 4 votes
# Innovation Award: Candidate C - 5 votes
